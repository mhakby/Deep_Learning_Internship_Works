# %% [markdown]
# Python Libraries: scikit-learn

# %%
# Jupyter Notebook - Python Libraries : scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# * With `train_test_split` we can separate to our dataset.
# * With `StandardScaler` we can scale our features values.
# * With `LabelEncoder` we can convert string value to numerical data.
# * With `classification_report` and `confusion_matrix` we can get training results.
